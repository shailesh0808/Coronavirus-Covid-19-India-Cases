# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nation_level = pd.read_csv("F:/shailesh_patil/covid-19_india_dataset/nation_level_daily.csv")

# %%
nation_level.head()
# Out:
#          Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0  30/01/2021                1                1                0
# 1  31/01/2021                0                1                0
# 2  01/02/2021                0                1                0
# 3  02/02/2021                1                2                0
# 4  03/02/2021                1                3                0
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0                0               0               0
# 1                0               0               0
# 2                0               0               0
# 3                0               0               0
# 4                0               0               0

# %%
nation_level.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             189 non-null    object
#  1   Daily Confirmed  189 non-null    int64
#  2   Total Confirmed  189 non-null    int64
#  3   Daily Recovered  189 non-null    int64
#  4   Total Recovered  189 non-null    int64
#  5   Daily Deceased   189 non-null    int64
#  6   Total Deceased   189 non-null    int64
# dtypes: int64(6), object(1)
# memory usage: 10.5+ KB

# %%
nation_level.describe()
# Out:
#        Daily Confirmed  Total Confirmed  Daily Recovered  Total Recovered  \
# count       189.000000     1.890000e+02       189.000000     1.890000e+02
# mean      10425.687831     3.018301e+05      7089.153439     1.823526e+05
# std       15444.992433     4.855878e+05     11578.243450     3.168678e+05
# min           0.000000     1.000000e+00         0.000000     0.000000e+00
# 25%          22.000000     1.460000e+02         1.000000     1.500000e+01
# 50%        2952.000000     4.277800e+04       962.000000     1.176300e+04
# 75%       13829.000000     3.958380e+05     10462.000000     2.142100e+05
# max       62170.000000     2.025423e+06     51368.000000     1.377275e+06
#
#        Daily Deceased  Total Deceased
# count      189.000000      189.000000
# mean       216.238095     7701.396825
# std        289.222383    11216.653140
# min          0.000000        0.000000
# 25%          0.000000        3.000000
# 50%         91.000000     1463.000000
# ...

# %%
nation_level.isnull().sum()
# Out:
# Date               0
# Daily Confirmed    0
# Total Confirmed    0
# Daily Recovered    0
# Total Recovered    0
# Daily Deceased     0
# Total Deceased     0
# dtype: int64

# %%
nation_level.boxplot(figsize = (10,6))
# Out:
# <AxesSubplot:>

# %%
nation_level.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             189 non-null    object
#  1   Daily Confirmed  189 non-null    int64
#  2   Total Confirmed  189 non-null    int64
#  3   Daily Recovered  189 non-null    int64
#  4   Total Recovered  189 non-null    int64
#  5   Daily Deceased   189 non-null    int64
#  6   Total Deceased   189 non-null    int64
# dtypes: int64(6), object(1)
# memory usage: 10.5+ KB

# %%
nation_level['Date'] = pd.to_datetime(nation_level['Date'])

# %%
nation_level
# Out:
#           Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0   2021-01-30                1                1                0
# 1   2021-01-31                0                1                0
# 2   2021-01-02                0                1                0
# 3   2021-02-02                1                2                0
# 4   2021-03-02                1                3                0
# ..         ...              ...              ...              ...
# 184 2021-02-08            52672          1804857            40355
# 185 2021-03-08            50488          1855345            43070
# 186 2021-04-08            51282          1906627            51220
# 187 2021-05-08            56626          1963253            45583
# 188 2021-06-08            62170          2025423            50141
#
#      Total Recovered  Daily Deceased  Total Deceased
# 0                  0               0               0
# 1                  0               0               0
# ...

# %%
nation_level.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             189 non-null    datetime64[ns]
#  1   Daily Confirmed  189 non-null    int64
#  2   Total Confirmed  189 non-null    int64
#  3   Daily Recovered  189 non-null    int64
#  4   Total Recovered  189 non-null    int64
#  5   Daily Deceased   189 non-null    int64
#  6   Total Deceased   189 non-null    int64
# dtypes: datetime64[ns](1), int64(6)
# memory usage: 10.5 KB

# %%
nation_level.to_csv("F:/shailesh_patil/covid-19_india_dataset/df cleaned/nation_level.csv")

# %%
nation_level
# Out:
#           Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0   2021-01-30                1                1                0
# 1   2021-01-31                0                1                0
# 2   2021-01-02                0                1                0
# 3   2021-02-02                1                2                0
# 4   2021-03-02                1                3                0
# ..         ...              ...              ...              ...
# 184 2021-02-08            52672          1804857            40355
# 185 2021-03-08            50488          1855345            43070
# 186 2021-04-08            51282          1906627            51220
# 187 2021-05-08            56626          1963253            45583
# 188 2021-06-08            62170          2025423            50141
#
#      Total Recovered  Daily Deceased  Total Deceased
# 0                  0               0               0
# 1                  0               0               0
# ...
