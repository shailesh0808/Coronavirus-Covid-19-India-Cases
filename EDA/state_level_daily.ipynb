# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
state_level = pd.read_csv("F:/shailesh_patil/covid-19_india_dataset/state_level_daily.csv")

# %%
state_level.head()
# Out:
#    Unnamed: 0        Date State  Confirmed  Deceased  Recovered  \
# 0           1  14/03/2020    AN          0         0          0
# 1           2  14/03/2020    AP          1         0          0
# 2           3  14/03/2020    AR          0         0          0
# 3           4  14/03/2020    AS          0         0          0
# 4           5  14/03/2020    BR          0         0          0
#
#                     State_Name
# 0  Andaman and Nicobar Islands
# 1               Andhra Pradesh
# 2            Arunachal Pradesh
# 3                        Assam
# 4                        Bihar

# %%
state_level.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5694 entries, 0 to 5693
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5694 non-null   int64
#  1   Date        5694 non-null   object
#  2   State       5694 non-null   object
#  3   Confirmed   5694 non-null   int64
#  4   Deceased    5694 non-null   int64
#  5   Recovered   5694 non-null   int64
#  6   State_Name  5694 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 311.5+ KB

# %%
state_level['Date'] = pd.to_datetime(state_level['Date'])

# %%
state_level.head()
# Out:
#    Unnamed: 0       Date State  Confirmed  Deceased  Recovered  \
# 0           1 2020-03-14    AN          0         0          0
# 1           2 2020-03-14    AP          1         0          0
# 2           3 2020-03-14    AR          0         0          0
# 3           4 2020-03-14    AS          0         0          0
# 4           5 2020-03-14    BR          0         0          0
#
#                     State_Name
# 0  Andaman and Nicobar Islands
# 1               Andhra Pradesh
# 2            Arunachal Pradesh
# 3                        Assam
# 4                        Bihar

# %%
state_level.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5694 entries, 0 to 5693
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5694 non-null   int64
#  1   Date        5694 non-null   datetime64[ns]
#  2   State       5694 non-null   object
#  3   Confirmed   5694 non-null   int64
#  4   Deceased    5694 non-null   int64
#  5   Recovered   5694 non-null   int64
#  6   State_Name  5694 non-null   object
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 311.5+ KB

# %%
state_level.isnull().sum()
# Out:
# Unnamed: 0    0
# Date          0
# State         0
# Confirmed     0
# Deceased      0
# Recovered     0
# State_Name    0
# dtype: int64

# %%
state_level.describe().transpose()
# Out:
#              count         mean          std     min      25%     50%  \
# Unnamed: 0  5694.0  2847.500000  1643.860548     1.0  1424.25  2847.5
# Confirmed   5694.0   709.546716  3569.190577 -1295.0     0.00    20.0
# Deceased    5694.0    14.589919    72.889425    -3.0     0.00     0.0
# Recovered   5694.0   481.645241  2605.743880   -19.0     0.00     5.0
#
#                 75%      max
# Unnamed: 0  4270.75   5694.0
# Confirmed    212.00  62170.0
# Deceased       3.00   2004.0
# Recovered    116.75  51368.0

# %%
state_level[state_level.Confirmed<0]
# Out:
#       Unnamed: 0       Date State  Confirmed  Deceased  Recovered  \
# 2445        2446 2020-05-15    PB         -3         0         82
# 2529        2530 2020-05-17    TR         -2         0         21
# 3389        3390 2020-08-06    UN       -773         0          0
# 3506        3507 2020-11-06    UN       -296         0          0
# 3545        3546 2020-12-06    UN       -616         0          0
# 3584        3585 2020-06-13    UN       -331         0          0
# 3623        3624 2020-06-14    UN       -548         0          0
# 3662        3663 2020-06-15    UN       -464         0          0
# 3726        3727 2020-06-17    ML         -1         0          3
# 3896        3897 2020-06-21    UN       -138         0          0
# 3935        3936 2020-06-22    UN      -1295         0          0
# 4091        4092 2020-06-26    UN       -370         0          0
# 4130        4131 2020-06-27    UN       -100         0          0
# ...

# %%
state_level.boxplot(figsize = (15,10))
# Out:
# <AxesSubplot:>

# %%
state_level.to_csv("F:\shailesh_patil\covid-19_india_dataset\df cleaned/state_level_daily.csv")
